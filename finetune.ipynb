# %% [markdown]
# # LoRA Finetuning

# %%
from google.colab import drive
import os

# project_path = '/content/drive/MyDrive/dl-proj'
# if not os.path.exists(project_path):
#     os.makedirs(project_path)
#     print(f"Created folder: {project_path}")
# else:
#     print(f"Folder already exists: {project_path}")

# os.chdir(project_path)
print(f"Current working directory: {os.getcwd()}")
print(f"Contents of the project folder: {os.listdir(os.getcwd())}")
# Out:
# Current working directory: /content
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10877/594789568.py in <cell line: 0>()
#      11 # os.chdir(project_path)
#      12 print(f"Current working directory: {os.getcwd()}")
# ---> 13 print(f"Contents of the project folder: {os.listdir(project_path)}")
#
# NameError: name 'project_path' is not defined

# %%
# %load_ext autoreload
# %autoreload 2
import dataset
import lora
import eval
# Out:
# sample_data
